# %% [markdown]
# ### Practice 1
# จงเขียนโปรแกรมรับพาสเวิร์ด
# (Password) จากผู้ใช้งาน แล้วระบุว่าพาสเวิร์ดนั้นมีระดับความแข็งแรง
# อย่างไร โดยระดับความแข็งแรงจะวัดได้จากคะแนนของพาสเวิร์ดดังตารางนี้
# - 0 – 20 very weak
# - 21 – 40 weak
# - 41 – 60 good
# - 61 – 80 strong
# - 81 – 100 very strong
#
# โดยการคิดคะแนนทำได้ดังนี้
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# <b>คุณลักษณะของโปรแกรม :
# - ต้องประกอบด้วยฟังค์ชั่นอย่างน้อย 3 ฟังค์ชั่น
# - ต้องเก็บพาสเวิร์ด ทั้งหมด ที่ผู้ใช้งาน กรอก ลงในไฟล์ password.txt
#
# ตัวอย่างหน้าจอและผลลัพธ์ของโปรแกรม
# ![image.png](attachment:image.png)

# %% [markdown]
# ตัวอย่างข้อมูลในไฟล์ password.txt
# ![image.png](attachment:image.png)

# %% [markdown]
# #### hint!!
# - .isupper() สามารถตรวจสอบว่าเป็นตัวพิมพ์ใหญ่หรือไม่
# - .islower() สามารถตรวจสอบว่าเป็นตัวพิมพ์เล็กหรือไม่
# - .isdigit() สามารถตรวจสอบว่าเป็นตัวเลขหรือไม่

# %%
a = '1'
a.isdigit()
# Out:
# True

# %%
b = 'a'
b.isupper()
# Out:
# False

# %% [markdown]
# ### Practice 2
# จงเขียนฟังก์ชันสำหรับเรียงลำดับข้อมูลตัวเลขจากน้อยไปมากภายใน list โดยห้ามใช้คำสั่ง sorted
# เช่น [5, 8, 2, 1, 4, 0, 9, 6] => [0, 1, 2, 4, 5, 6, 8, 9]
