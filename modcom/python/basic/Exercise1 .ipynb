# %% [markdown]
# ### Practice 1
# จงเขียนโปรแกรมรับค่าน้ำหนักและส่วนสูง จากนั้นแสดงค่า BMI พร้อมการแปลผล
# โดย Body Mass Index (BMI) มีสูตรการคำนวณ = น้ำหนักตัว[Kg] / (ส่วนสูง[m] ยกกำลังสอง)
#
# โดยสามารถแปลผลค่า BMI ได้ดังนี้
# + ค่า BMI < 18.5           แสดงถึง            อยู่ในเกณฑ์น้ำหนักน้อยหรือผอม
#
# + ค่า BMI 18.5 – 22.90     แสดงถึง            อยู่ในเกณฑ์ปกติ
#
# + ค่า BMI 23 – 24.90       แสดงถึง            น้ำหนักเกิน
#
# + ค่า BMI 25 – 29.90       แสดงถึง            โรคอ้วนระดับที่ 1
#
# + ค่า BMI 30 ขึ้นไป          แสดงถึง            โรคอ้วนระดับที่ 2

# %% [markdown]
# ### Practice 2
# ชมรมเลี้ยงวัวในโรงเรียนของคุณต้องการให้คุณช่วยเหลือ เนื่องจากช่วงนี้เกิดเหตุการณ์วัวหายไปจากเขตกินหญ้าของโรงเรียนจำนวนมาก ทางโรงเรียนที่กลัวว่าวัวจะหายไปจนหมดทำให้ไม่เหลือให้นักเรียนได้ศึกษาเรียนรู้ จึงได้มาปรึกษากับคุณให้เขียนโปรแกรมในการหาพื้นที่คอกที่จะต้องล้อม โดยทางโรงเรียนจะวัดความยาวด้านกว้างกับด้านยาวมาให้
#
# สูตรหาพื้นที่คือ กว้าง x ยาว
#
# ตัวอย่าง
#
# ข้อมูลนำเข้า	5,12
# ข้อมูลส่งออก	60.0

# %% [markdown]
# ### Practice 3
# #### Practice 3.1
# จงช่วยอาจารย์ในการสร้างโปรแกรมประเมินผลการเรียนของนักเรียนที่มีคะแนนตั้งแต่ 0-100 ซึ่งจะมีการรับค่าคะแนนเข้าไปในโปรแกรม เมื่อกรอกคะแนนเข้าไปแล้วจะทำการคำนวณผลการเรียน จากนั้นแสดงผลการเรียนนั้นทางหน้าจอ โดยมีเงื่อนไขดังนี้
# + คะแนนน้อยกว่า 50 คะแนน เกรด 0
# + คะแนนมากกว่าเท่ากับ 50 คะแนน แต่น้อยกว่า 60 คะแนน เกรด 1
# + คะแนนมากกว่าเท่ากับ 60 คะแนน แต่น้อยกว่า 70 คะแนน เกรด 2
# + คะแนนมากกว่าเท่ากับ 70 คะแนน แต่น้อยกว่า 80 คะแนน เกรด 3
# + คะแนนมากกว่าเท่ากับ 80 คะแนน เกรด 4
# + นอกจากนั้นแสดง " กรอกข้อมูลผิดโปรดกรอกอีกครั้ง "

# %% [markdown]
# #### Practice 3.2
# จงต่อยอดโปรแกรมในข้อ 1.1 โดยหลังจากคำนวณค่าผลการเรียนแล้วจะทำการเก็บไว้ใน list โปรแกรมนี้สามารถทำงานได้ต่อเนื่องจนกว่าผู้ใช้จะกรอกข้อมูลเป็น "END"

# %% [markdown]
# #### Practice 3.3
# จงประเมินผลการเรียนของชุดคะแนนของนักเรียนจำนวน 40 คนต่อไปนี้ จากนั้นแสดงผลการประเมินทั้งหมด
#
# [75, 17, 83, 12, 80, 48, 70, 77, 15, 97, 45, 16, 96, 88, 33, 67, 97, 88, 79, 83, 14, 86, 23, 36, 19, 58, 33,  5, 70, 86, 76, 97, 91, 45, 54, 45, 80, 16, 53,  4]

# %% [markdown]
# ### Practice 4
# จงเขียนโปรแกรมที่รับตำแหน่งของกระดานหมากรุกจากผู้ใช้ และระบุว่าสี่เหลี่ยมที่ตำแหน่งนั้นเป็นสีดำหรือสีขาว โดยตำแหน่งของกระดานหมากรุกจะระบุในรูปแบบของตัวอักษรและตัวเลข เช่น 'a1', 'h8', 'c3' เป็นต้น โปรแกรมจะทำงานจนกว่าผู้ใช้จะป้อนคำว่า 'END'![chess%20board.jpg](attachment:chess%20board.jpg)

# %% [markdown]
# #### ตัวอย่าง output
# ![chess%20board%20output.png](attachment:chess%20board%20output.png)

# %% [markdown]
# ### Practice 5
# จงเขียนโปรแกรมสำหรับคำนวณราคาสินค้า โดยเมื่อเริ่มการทำงานเจ้าหน้าที่สามารถกรอกข้อมูลชื่อสินค้าและราคาสินค้า โดยเจ้าหน้าที่สามารถป้อนค่าของสินค้ารายการถัดไปได้เรื่อย ๆ จนกว่าจะป้อนค้า "END" แปลว่าจบรายการสำหรับลูกค้าคนนั้น เมื่อจบโปรแกรมจะแสดงผลของชื่อและราคาสินค้าทั้งหมด, vat 7% และจำนวนเงินที่ลูกค้าต้องชำระทั้งหมด(รวม vat แล้ว)
